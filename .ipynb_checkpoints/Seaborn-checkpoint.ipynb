# %% [markdown]
# # Seaborn
#
# https://seaborn.pydata.org/

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Seaborn içindeki data setleri

# %%
sns.get_dataset_names() #seaborn data setlerini gördüm
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips") #seaborn data setini okudum

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 87        18.28  4.00    Male     No  Thur   Lunch     2
# 74        14.73  2.20  Female     No   Sat  Dinner     2
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 104       20.92  4.08  Female     No   Sat  Dinner     2
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4
# 97        12.03  1.50    Male    Yes   Fri  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 91        22.49  3.50    Male     No   Fri  Dinner     2
# 50        12.54  2.50    Male     No   Sun  Dinner     2

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Scatter Plot
#
# Dağılım grafikleri, farklı özelliklerin birbiriyle olan ilişkisini (korelasyonu) görüntülemek için kullanılır.

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip")

plt.show()

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = tips)

plt.show()

# %%
sns.regplot(x = "total_bill", y = "tip", data = tips);

# %% [markdown]
# ## Figsize

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(x = tips["total_bill"], y = tips["tip"])

plt.show()

# %% [markdown]
# ## Hue

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = "smoker" )

plt.show()

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = "sex" )

plt.show()

# %%
plt.figure(figsize = (10, 5))

sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = "day" )

plt.show()
